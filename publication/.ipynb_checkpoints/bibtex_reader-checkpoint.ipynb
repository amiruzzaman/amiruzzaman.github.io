# %%
# !pip install bibtexparser
# Out:
# ...
#      ---------------------------------------- 55.1/55.1 KB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for bibtexparser, since package 'wheel' is not installed.
# ...
#   Running setup.py install for bibtexparser: started
#   Running setup.py install for bibtexparser: finished with status 'done'
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\users\mamiruzz\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
# https://stackoverflow.com/questions/9235853/convert-bibtex-file-to-database-entries-using-python
import bibtexparser
import pandas as pd

with open("publication_bib.txt") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
    
df = pd.DataFrame(bib_database.entries)
# selection = df[['doi', 'number']]
df.to_csv('temp.csv', index=False)
# Out:
# Entry type thesis not standard. Not considered.
# -------------------------------------------------
# KeyError        Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\bibtexparser\bibdatabase.py in expand_string(self, name)
#     104             return BibDataStringExpression.expand_if_expression(
# --> 105                 self.strings[name])
#     106         except KeyError:
#
# KeyError: 'july'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedString Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25524/1430849104.py in <module>
#       4
#       5 with open("publication_bib.txt") as bibtex_file:
# ----> 6     bib_database = bibtexparser.load(bibtex_file)
#       7
#       8 df = pd.DataFrame(bib_database.entries)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\bibtexparser\__init__.py in load(bibtex_file, parser)
#      67     if parser is None:
# ...

# %%
df.head(2)
# Out:
#    ENTRYTYPE                          ID abstract archiveprefix  \
# 0  phdthesis     amiruzzaman2021studying      NaN           NaN
# 1    article  amiruzzaman2021classifying      NaN           NaN
#
#   article-number                                             author bibsource  \
# 0            NaN                                    Amiruzzaman, Md       NaN
# 1            NaN  Amiruzzaman, Md and Curtis, Andrew and Zhao, Y...       NaN
#
#   biburl booktitle                                         doi  ...  number  \
# 0    NaN       NaN                                         NaN  ...     NaN
# 1    NaN       NaN  https://doi.org/10.1007/s42001-021-00107-x  ...     NaN
#
#   organization  pages publisher                 school timestamp  \
# 0          NaN    NaN       NaN  Kent State University       NaN
# 1          NaN  1--25  Springer                    NaN       NaN
#
#                                                title  \
# ...

# %%
df.ID
# Out:
# 0               amiruzzaman2021studying
# 1            amiruzzaman2021classifying
# 2                        rizvee2021data
# 3     DBLP:journals/corr/abs-2106-04575
# 4             amiruzzaman2021evaluation
# 5                               9318975
# 6                               9318786
# 7                           sym12071075
# 8                               9044257
# 9                               9071138
# 10                            s20236990
# 11    https://doi.org/10.1111/cgf.13995
# 12              10.2312:eurova.20201091
# 13             amiruzzaman2019assessing
# 14             amiruzzaman2016exploring
# 15            amiruzzaman2018prediction
# 16        amiruzzaman2011steganographic
# 17               amiruzzaman2010minimum
# 18                              1307869
# 19                         md2010covert
# 20              amiruzzaman2010analysis
# 21            amiruzzaman2010concurrent
# 22              amiruzzaman2009improved
# ...

# %%
'''sort pandas dataframe'''
# https://stackoverflow.com/questions/37787698/how-to-sort-pandas-dataframe-from-one-column
# Use sort_values to sort the df by a specific column's values:
# df.sort_values('year')
df = df.sort_values(by=['year'], ascending=False)
df.head(5)
# Out:
#        ENTRYTYPE                                 ID  \
# 0      phdthesis            amiruzzaman2021studying
# 2  inproceedings                     rizvee2021data
# 3           misc  DBLP:journals/corr/abs-2106-04575
# 1        article         amiruzzaman2021classifying
# 8  inproceedings                            9044257
#
#                                             abstract archiveprefix  \
# 0                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN         arXiv
# 1                                                NaN           NaN
# 8  This paper presents a new application for mult...           NaN
#
#   article-number                                             author  \
# 0            NaN                                    Amiruzzaman, Md
# 2            NaN  Rizvee, Md Mashfiq and Amiruzzaman, Md and Isl...
# ...

# %%
# final_df = df.sort_values(by=['year'], ascending=False)
# final_df

# %%
'''iterate dataframe'''
print('\\begin{enumerate}')
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
for index, row in df.iterrows():
    '''string.format python'''
    pub = "\\item \\publication[{0}]".format(row['ID'])
    '''string replace python'''
#     https://www.w3schools.com/python/ref_string_replace.asp
    pub = pub.replace("[", "{")
    pub = pub.replace("]", "}")
    print('\t' +pub)
#     print(row['ID'], row['year'])
print('\\end{enumerate}')
# Out:
# \begin{enumerate}
# 	\item \publication{amiruzzaman2021studying}
# 	\item \publication{rizvee2021data}
# 	\item \publication{DBLP:journals/corr/abs-2106-04575}
# 	\item \publication{amiruzzaman2021classifying}
# 	\item \publication{9044257}
# 	\item \publication{10.2312:eurova.20201091}
# 	\item \publication{https://doi.org/10.1111/cgf.13995}
# 	\item \publication{s20236990}
# 	\item \publication{9071138}
# 	\item \publication{sym12071075}
# 	\item \publication{9318786}
# 	\item \publication{9318975}
# 	\item \publication{amiruzzaman2021evaluation}
# 	\item \publication{amiruzzaman2019assessing}
# 	\item \publication{amiruzzaman2018prediction}
# 	\item \publication{amiruzzaman2016exploring}
# 	\item \publication{amiruzzaman2011steganographic}
# 	\item \publication{amiruzzaman2010analysis}
# 	\item \publication{amiruzzaman2010concurrent}
# 	\item \publication{amiruzzaman2010minimum}
# 	\item \publication{md2010covert}
# 	\item \publication{amiruzzaman2009improved}
# ...
