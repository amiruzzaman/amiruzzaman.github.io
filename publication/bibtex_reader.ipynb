# %%
# !pip install bibtexparser
# Out:
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.1.tar.gz (55 kB)
#      ---------------------------------------- 55.1/55.1 KB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.3 in c:\users\mamiruzz\appdata\local\programs\python\python38-32\lib\site-packages (from bibtexparser) (2.4.7)
# Using legacy 'setup.py install' for bibtexparser, since package 'wheel' is not installed.
# Installing collected packages: bibtexparser
#   Running setup.py install for bibtexparser: started
#   Running setup.py install for bibtexparser: finished with status 'done'
# Successfully installed bibtexparser-1.4.1
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\users\mamiruzz\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
# https://stackoverflow.com/questions/9235853/convert-bibtex-file-to-database-entries-using-python
import bibtexparser
import pandas as pd

with open("publication_bib2.txt") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
    
df = pd.DataFrame(bib_database.entries)
# selection = df[['doi', 'number']]
df.to_csv('temp.csv', index=False)
# Out:
# Entry type thesis not standard. Not considered.

# %%
df.head(2)
# Out:
#                                                  url                 school  \
# 0  http://rave.ohiolink.edu/etdc/view?acc_num=ken...  Kent State University
# 1  https://link.springer.com/article/10.1007/s420...                    NaN
#
#    year                                             author  \
# 0  2021                                    Amiruzzaman, Md
# 1  2021  Amiruzzaman, Md and Curtis, Andrew and Zhao, Y...
#
#                                                title  ENTRYTYPE  \
# 0  Studying geospatial urban visual appearance an...  phdthesis
# 1  Classifying crime places by neighborhood visua...    article
#
#                            ID publisher  \
# 0     amiruzzaman2021studying       NaN
# 1  amiruzzaman2021classifying  Springer
#
#                                           doi       pages  ... issn keywords  \
# 0                                         NaN         NaN  ...  NaN      NaN
# 1  https://doi.org/10.1007/s42001-021-00107-x  813â€“-837  ...  NaN      NaN
#
#   article-number organization presentation chapter note abstractnote numpages  \
# 0            NaN          NaN          NaN     NaN  NaN          NaN      NaN
# 1            NaN          NaN          NaN     NaN  NaN          NaN      NaN
#
#   issue_date
# 0        NaN
# 1        NaN
#
# [2 rows x 34 columns]

# %%
df.ID
# Out:
# 0               amiruzzaman2021studying
# 1            amiruzzaman2021classifying
# 2          10.1007/978-981-16-0586-4_12
# 3     DBLP:journals/corr/abs-2106-04575
# 4             amiruzzaman2021evaluation
#                     ...
# 63              10.5555/3636988.3637012
# 64                         info14100569
# 65                    wu2024visualizing
# 66                  nobel2024enhanching
# 67                            Jisha2024
# Name: ID, Length: 68, dtype: object

# %%
'''sort pandas dataframe'''
# https://stackoverflow.com/questions/37787698/how-to-sort-pandas-dataframe-from-one-column
# Use sort_values to sort the df by a specific column's values:
# df.sort_values('year')
df = df.sort_values(by=['year'], ascending=False)
df.head(5)
# Out:
#                                                   url school  year  \
# 67  https://rebicte.org/index.php/rebicte/article/...    NaN  2024
# 66  https://ijournalse.org/index.php/ESJ/article/v...    NaN  2024
# 65      https://ieeexplore.ieee.org/document/10504858    NaN  2024
# 59  https://rebicte.org/index.php/rebicte/article/...    NaN  2023
# 56                                                NaN    NaN  2023
#
#                                                author  \
# 67  Jisha Sheela Kumar and Md Amiruzzaman and Ashi...
# 66  S M Nuruzzaman Nobel and Omar Faruque Sifat an...
# 65  Wu, Tsung Heng and Amiruzzaman, Md and Zhao, Y...
# 59  Rini, Fariha Sultana and Jebin, Somiya Assir a...
# 56  Amiruzzaman, Md and Zhao, Ye and Amiruzzaman, ...
#
#                                                 title ENTRYTYPE  \
# 67  Predictive Analytics in Law Enforcement: Unvei...   article
# 66  Enhancing GI Cancer Radiation Therapy: Advance...   article
# 65  Visualizing Routes With AI-Discovered Street-V...   article
# 59  Predicting Optimum Lockdown Pattern of Epidemi...   article
# 56  An AI-based framework for studying visual dive...   article
#
#                      ID publisher                                         doi  \
# 67            Jisha2024       NaN                   10.56801/rebicte.v10i.188
# 66  nobel2024enhanching       NaN                 10.28991/ESJ-2024-08-03-012
# 65    wu2024visualizing      IEEE                   10.1109/TCSS.2024.3382944
# 59   rini2023predicting       NaN    https://doi.org/10.56801/rebicte.v9i.153
# 56    amiruzzaman2022ai  Springer  https://doi.org/10.1007/s42001-022-00197-1
#
#         pages  ... issn keywords article-number organization presentation  \
# 67    36â€“59  ...  NaN      NaN            NaN          NaN          NaN
# 66  999--1015  ...  NaN      NaN            NaN          NaN          NaN
# 65        NaN  ...  NaN      NaN            NaN          NaN          NaN
# 59      1--20  ...  NaN      NaN            NaN          NaN          NaN
# 56    315-337  ...  NaN      NaN            NaN          NaN          NaN
#
#    chapter note                                       abstractnote numpages  \
# 67     NaN  NaN  &amp;lt;p&amp;gt;Urban crime poses multifacete...      NaN
# 66     NaN  NaN                                                NaN      NaN
# 65     NaN  NaN                                                NaN      NaN
# 59     NaN  NaN                                                NaN      NaN
# 56     NaN  NaN                                                NaN      NaN
#
#    issue_date
# 67        NaN
# 66        NaN
# 65        NaN
# 59        NaN
# 56        NaN
#
# [5 rows x 34 columns]

# %%
gk = df.groupby('ENTRYTYPE')
gk.head(10)
# Out:
#                                                   url                 school  \
# 67  https://rebicte.org/index.php/rebicte/article/...                    NaN
# 66  https://ijournalse.org/index.php/ESJ/article/v...                    NaN
# 65      https://ieeexplore.ieee.org/document/10504858                    NaN
# 59  https://rebicte.org/index.php/rebicte/article/...                    NaN
# 56                                                NaN                    NaN
# 57   http://aetic.theiaer.org/archive/v7/v7n1/p1.html                    NaN
# 58             https://www.mdpi.com/2073-431X/12/3/50                    NaN
# 60                  https://doi.org/10.1063/5.0127776                    NaN
# 61  https://rebicte.org/index.php/rebicte/article/...                    NaN
# 62                                                NaN                    NaN
# 50   https://arc.aiaa.org/doi/abs/10.2514/6.2022-3416                    NaN
# 46  https://link.springer.com/chapter/10.1007/978-...                    NaN
# 55       https://ieeexplore.ieee.org/document/9927881                    NaN
# 47  https://doi.ieeecomputersociety.org/10.1109/DA...                    NaN
# 45       https://ieeexplore.ieee.org/document/9706544                    NaN
# 42       https://ieeexplore.ieee.org/document/9667925                    NaN
# 37                   https://arxiv.org/abs/2107.14140                    NaN
# 36       https://ieeexplore.ieee.org/document/9642542                    NaN
# 0   http://rave.ohiolink.edu/etdc/view?acc_num=ken...  Kent State University
# 2                                                 NaN                    NaN
# 3                    https://arxiv.org/abs/2106.04575                    NaN
# 5   https://ieeexplore.ieee.org/abstract/document/...                    NaN
# 9   https://ieeexplore.ieee.org/abstract/document/...                    NaN
# 13  http://rave.ohiolink.edu/etdc/view?acc_num=ken...  Kent State University
# 39                                                NaN                    NaN
# 14  http://rave.ohiolink.edu/etdc/view?acc_num=ken...  Kent State University
# 40                                                NaN                    NaN
# 16  http://rave.ohiolink.edu/etdc/view?acc_num=ken...  Kent State University
# 17                                                         Sejong University
#
#     year                                             author  \
# 67  2024  Jisha Sheela Kumar and Md Amiruzzaman and Ashi...
# 66  2024  S M Nuruzzaman Nobel and Omar Faruque Sifat an...
# 65  2024  Wu, Tsung Heng and Amiruzzaman, Md and Zhao, Y...
# 59  2023  Rini, Fariha Sultana and Jebin, Somiya Assir a...
# 56  2023  Amiruzzaman, Md and Zhao, Ye and Amiruzzaman, ...
# 57  2023  Md. Rajibul Islam and Md. Asif Mahmod Tusher S...
# 58  2023  Salleh, Marhanum Che Mohd and Nor, Rizal Mohd ...
# 60  2023  Bhat, Asif and Nor, Rizal Mohd. and Amiruzzama...
# 61  2023  Rishita Gadde and Md Amiruzzaman and Richard B...
# 62  2023  Konduru, S. and Amiruzzaman, M. and Avina, V. ...
# 50  2022  David Sheets and Md Amiruzzaman and D. Blake S...
# 46  2022  Bhati, Deepshikha and Amiruzzaman, Md and Jamo...
# 55  2022          Amiruzzaman, Stefanie and Amiruzzaman, Md
# 47  2021          Amiruzzaman, Stefanie and Amiruzzaman, Md
# 45  2021  Bhat, Asif and Nor, Rizal Mohd. and Mansor, Ha...
# 42  2021  Amiruzzaman, Md and Rahman, Rashik and Islam, ...
# 37  2021  Bhat, Asif and Nor, Rizal Mohd and Amiruzzaman...
# 36  2021  Islam, Mahnaz Rafia and Jenny, Israt Jahan and...
# 0   2021                                    Amiruzzaman, Md
# 2   2021  Md. Mashfiq Rizvee and Md Amiruzzaman and Md. ...
# 3   2021  Hassnain ul hassan and Rizal Mohd Nor and Md A...
# 5   2020  Akash, Md. Azim Hossain and Begum, Nasima and ...
# 9   2020                Amiruzzaman, Md and Nor, Rizal Mohd
# 13  2019                                    Amiruzzaman, Md
# 39  2018  Kosko, Karl W and Sobolewski-McMahon, Lauren a...
# 14  2016                                    Amiruzzaman, Md
# 40  2014  Kosko, Karl W and Sobolewski-McMahon, Lauren a...
# 16  2011                                    Amiruzzaman, Md
# 17  2008                                    Amiruzzaman, Md
#
#                                                 title      ENTRYTYPE  \
# 67  Predictive Analytics in Law Enforcement: Unvei...        article
# 66  Enhancing GI Cancer Radiation Therapy: Advance...        article
# 65  Visualizing Routes With AI-Discovered Street-V...        article
# 59  Predicting Optimum Lockdown Pattern of Epidemi...        article
# 56  An AI-based framework for studying visual dive...        article
# 57  An Efficient Technique for Recognizing Tomato ...        article
# 58  Constructing a Shariah Document Screening Prot...        article
# 60  {An assessment and comparative analysis of tra...        article
# 61        Estimate House Price Using Machine Learning        article
# 62  Plant Disease Detection and Classification Usi...        article
# 50  AVES: A data-driven approach for airman certif...  inproceedings
# 46  Interactive Visualization andÂ Capture ofÂ Geo...  inproceedings
# 55  Explore the Relationships Between Studentsâ€™ ...  inproceedings
# 47  Students' Academic Performance Multitasking an...  inproceedings
# 45  Leveraging Decentralized Internet of Things (I...  inproceedings
# 42  Evaluation of DBSCAN algorithm on different pr...  inproceedings
# 37  Methodology and Analysis of Smart Contracts in...           misc
# 36  Clustering Algorithms to Analyze the Road Traf...  inproceedings
# 0   Studying geospatial urban visual appearance an...      phdthesis
# 2   Data Mining and Visualization toÂ Understand A...  inproceedings
# 3   {DNS} attack mitigation Using OpenStack Isolation           misc
# 5   User Authentication Through Pen Tablet Data Us...  inproceedings
# 9   Hide Secret Information in Blocks: Minimum Dis...  inproceedings
# 13  Assessing the psychometric properties of newly...      phdthesis
# 39  Growing in number: Research on mathematical te...   incollection
# 14  Exploring preservice teachers' understanding o...      phdthesis
# 40  Few in number: Research on mathematical teachi...   incollection
# 16  Steganographic covert communication channels a...  mastersthesis
# 17  The design and implementation of the embedded ...  mastersthesis
#
#                                    ID  \
# 67                          Jisha2024
# 66                nobel2024enhanching
# 65                  wu2024visualizing
# 59                 rini2023predicting
# 56                  amiruzzaman2022ai
# 57    rajibulislam2022hyperparameters
# 58                  computers12030050
# 60                  10.1063/5.0127776
# 61                         Gadde_2023
# 62            10.5555/3636988.3637006
# 50            doi:10.2514/6.2022-3416
# 46                   dbhati2021mobile
# 55                            9927881
# 47                            9730236
# 45                            9706544
# 42                            9667925
# 37                bhat2021methodology
# 36                            9642542
# 0             amiruzzaman2021studying
# 2        10.1007/978-981-16-0586-4_12
# 3   DBLP:journals/corr/abs-2106-04575
# 5                             9318975
# 9                             9071138
# 13           amiruzzaman2019assessing
# 39                      kosko2018grow
# 14           amiruzzaman2016exploring
# 40                       kosko2014few
# 16      amiruzzaman2011steganographic
# 17      amiruzzaman2008embeddedsejong
#
#                                             publisher  \
# 67                                                NaN
# 66                                                NaN
# 65                                               IEEE
# 59                                                NaN
# 56                                           Springer
# 57  International Association for Educators and Re...
# 58                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62      Consortium for Computing Sciences in Colleges
# 50                                                NaN
# 46                  Springer International Publishing
# 55                              IEEE Computer Society
# 47                              IEEE Computer Society
# 45                                               IEEE
# 42                                               IEEE
# 37                                              ArXiv
# 36                                               IEEE
# 0                                                 NaN
# 2                                  Springer Singapore
# 3                                               ArXiv
# 5                                                IEEE
# 9                                                IEEE
# 13                                                NaN
# 39                          Pittsburgh, PA: ETC Press
# 14                                                NaN
# 40                          Pittsburgh, PA: ETC Press
# 16                                                NaN
# 17                                                NaN
#
#                                                   doi      pages  ...  \
# 67                          10.56801/rebicte.v10i.188    36â€“59  ...
# 66                        10.28991/ESJ-2024-08-03-012  999--1015  ...
# 65                          10.1109/TCSS.2024.3382944        NaN  ...
# 59           https://doi.org/10.56801/rebicte.v9i.153      1--20  ...
# 56         https://doi.org/10.1007/s42001-022-00197-1    315-337  ...
# 57         https://doi.org/10.33166/AETiC.2023.01.001       1-14  ...
# 58          https://doi.org/10.3390/computers12030050        NaN  ...
# 60                                  10.1063/5.0127776        NaN  ...
# 61                           10.56801/rebicte.v9i.156    41â€“58  ...
# 62                                                NaN    66â€“75  ...
# 50                                10.2514/6.2022-3416      1--14  ...
# 46       https://doi.org/10.1007/978-3-030-98404-5_25   260--271  ...
# 55     10.1109/DASC/PiCom/CBDCom/Cy55231.2022.9927881        1-6  ...
# 47  10.1109/DASC-PICom-CBDCom-CyberSciTech52372.20...    863-866  ...
# 45                     10.1109/ICSIoT55070.2021.00010        1-6  ...
# 42                  10.1109/ICEEICT53905.2021.9667925        1-6  ...
# 37                                                NaN        NaN  ...
# 36                    10.1109/ICSCT53883.2021.9642542       1--6  ...
# 0                                                 NaN        NaN  ...
# 2                        10.1007/978-981-16-0586-4_12   143--154  ...
# 3                                                 NaN        NaN  ...
# 5                     10.1109/ICKII50300.2020.9318975    208-211  ...
# 9                      10.1109/SPIN48934.2020.9071138    107-112  ...
# 13                                                NaN        NaN  ...
# 39             https://www.doi.org/10.1184/R1/6686813   289--302  ...
# 14                                                NaN        NaN  ...
# 40             https://www.doi.org/10.1184/R1/6686810   163--177  ...
# 16                                                NaN        NaN  ...
# 17                                                NaN        NaN  ...
#
#          issn                                           keywords  \
# 67        NaN                                                NaN
# 66        NaN                                                NaN
# 65        NaN                                                NaN
# 59        NaN                                                NaN
# 56        NaN                                                NaN
# 57        NaN                                                NaN
# 58  2073-431X                                                NaN
# 60  0094-243X                                                NaN
# 61        NaN                                                NaN
# 62  1937-4771                                                NaN
# 50        NaN                                                NaN
# 46        NaN                                                NaN
# 55
# 47        NaN  social networking (online);blogs;big data;mult...
# 45
# 42
# 37        NaN                                                NaN
# 36
# 0         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 5
# 9   2688-769X
# 13        NaN                                                NaN
# 39        NaN                                                NaN
# 14        NaN                                                NaN
# 40        NaN                                                NaN
# 16        NaN                                                NaN
# 17        NaN                                                NaN
#
#    article-number organization                             presentation  \
# 67            NaN          NaN                                      NaN
# 66            NaN          NaN                                      NaN
# 65            NaN          NaN                                      NaN
# 59            NaN          NaN                                      NaN
# 56            NaN          NaN                                      NaN
# 57            NaN          NaN                                      NaN
# 58             50          NaN                                      NaN
# 60            NaN          NaN                                      NaN
# 61            NaN          NaN                                      NaN
# 62            NaN          NaN                                      NaN
# 50            NaN          NaN  https://doi.org/10.2514/6.2022-3416.vid
# 46            NaN          NaN                                      NaN
# 55            NaN          NaN                                      NaN
# 47            NaN          NaN                                      NaN
# 45            NaN          NaN                                      NaN
# 42            NaN          NaN                                      NaN
# 37            NaN          NaN                                      NaN
# 36            NaN          NaN                                      NaN
# 0             NaN          NaN                                      NaN
# 2             NaN          NaN                                      NaN
# 3             NaN          NaN                                      NaN
# 5             NaN          NaN                                      NaN
# 9             NaN          NaN                                      NaN
# 13            NaN          NaN                                      NaN
# 39            NaN          NaN                                      NaN
# 14            NaN          NaN                                      NaN
# 40            NaN          NaN                                      NaN
# 16            NaN          NaN                                      NaN
# 17            NaN          NaN                                      NaN
#
#    chapter    note                                       abstractnote  \
# 67     NaN     NaN  &amp;lt;p&amp;gt;Urban crime poses multifacete...
# 66     NaN     NaN                                                NaN
# 65     NaN     NaN                                                NaN
# 59     NaN     NaN                                                NaN
# 56     NaN     NaN                                                NaN
# 57     NaN     NaN                                                NaN
# 58     NaN     NaN                                                NaN
# 60     NaN  020011                                                NaN
# 61     NaN     NaN  &amp;lt;p&amp;gt;The House Price Index (HPI) i...
# 62     NaN     NaN                                                NaN
# 50             NaN                                                NaN
# 46     NaN     NaN                                                NaN
# 55     NaN     NaN                                                NaN
# 47     NaN     NaN                                                NaN
# 45     NaN     NaN                                                NaN
# 42     NaN     NaN                                                NaN
# 37     NaN     NaN                                                NaN
# 36     NaN     NaN                                                NaN
# 0      NaN     NaN                                                NaN
# 2      NaN     NaN                                                NaN
# 3      NaN     NaN                                                NaN
# 5      NaN     NaN                                                NaN
# 9      NaN     NaN                                                NaN
# 13     NaN     NaN                                                NaN
# 39     NaN     NaN                                                NaN
# 14     NaN     NaN                                                NaN
# 40     NaN     NaN                                                NaN
# 16     NaN     NaN                                                NaN
# 17     NaN     NaN                                                NaN
#
#    numpages    issue_date
# 67      NaN           NaN
# 66      NaN           NaN
# 65      NaN           NaN
# 59      NaN           NaN
# 56      NaN           NaN
# 57      NaN           NaN
# 58      NaN           NaN
# 60      NaN           NaN
# 61      NaN           NaN
# 62       10  October 2023
# 50      NaN           NaN
# 46      NaN           NaN
# 55      NaN           NaN
# 47      NaN           NaN
# 45      NaN           NaN
# 42      NaN           NaN
# 37      NaN           NaN
# 36      NaN           NaN
# 0       NaN           NaN
# 2       NaN           NaN
# 3       NaN           NaN
# 5       NaN           NaN
# 9       NaN           NaN
# 13      NaN           NaN
# 39      NaN           NaN
# 14      NaN           NaN
# 40      NaN           NaN
# 16      NaN           NaN
# 17      NaN           NaN
#
# [29 rows x 34 columns]

# %%
# final_df = df.sort_values(by=['year'], ascending=False)
# final_df

# %%
'''iterate dataframe'''
print('\\begin{enumerate}')
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
for index, row in df.iterrows():
    '''string.format python'''
    pub = "\\item \\publication[{0}]".format(row['ID'])
    '''string replace python'''
#     https://www.w3schools.com/python/ref_string_replace.asp
    pub = pub.replace("[", "{")
    pub = pub.replace("]", "}")
    print('\t' +pub)
#     print(row['ID'], row['year'])
print('\\end{enumerate}')
# Out:
# \begin{enumerate}
# 	\item \publication{Jisha2024}
# 	\item \publication{nobel2024enhanching}
# 	\item \publication{wu2024visualizing}
# 	\item \publication{rini2023predicting}
# 	\item \publication{amiruzzaman2022ai}
# 	\item \publication{rajibulislam2022hyperparameters}
# 	\item \publication{computers12030050}
# 	\item \publication{10.1063/5.0127776}
# 	\item \publication{Gadde_2023}
# 	\item \publication{10.5555/3636988.3637006}
# 	\item \publication{10.5555/3636988.3637012}
# 	\item \publication{info14100569}
# 	\item \publication{doi:10.2514/6.2022-3416}
# 	\item \publication{9555830}
# 	\item \publication{dbhati2021mobile}
# 	\item \publication{Jamonnak2022VisualCommunity}
# 	\item \publication{amiruzzaman2022dbscanmist}
# 	\item \publication{jisis22-12-3-01}
# 	\item \publication{asif2022methodology}
# 	\item \publication{Amiruzzaman2022ReBiCTE}
# 	\item \publication{socsci11090404}
# 	\item \publication{9927881}
# 	\item \publication{9730236}
# 	\item \publication{amiruzzaman2021classifying}
# 	\item \publication{9706544}
# 	\item \publication{9667925}
# 	\item \publication{bhatblockchain}
# 	\item \publication{bhat2021methodology}
# 	\item \publication{9642542}
# 	\item \publication{amiruzzaman2021studying}
# 	\item \publication{10.1007/978-981-16-0586-4_12}
# 	\item \publication{DBLP:journals/corr/abs-2106-04575}
# 	\item \publication{9318975}
# 	\item \publication{9071138}
# 	\item \publication{wu2020interactive}
# 	\item \publication{https://doi.org/10.1111/cgf.13995}
# 	\item \publication{amiruzzaman2021evaluation}
# 	\item \publication{s20236990}
# 	\item \publication{9044257}
# 	\item \publication{sym12071075}
# 	\item \publication{9318786}
# 	\item \publication{10.1007/978-3-030-02686-8_23}
# 	\item \publication{amiruzzaman2019assessing}
# 	\item \publication{kosko2018grow}
# 	\item \publication{Amiruzzaman2020PreserviceMT}
# 	\item \publication{Amiruzzaman2020ExploringSU}
# 	\item \publication{amiruzzaman2016exploring}
# 	\item \publication{kosko2014few}
# 	\item \publication{amiruzzaman2011steganographic}
# 	\item \publication{10.1007/978-3-642-17578-7_16}
# 	\item \publication{10.1007/978-3-642-13365-7_5}
# 	\item \publication{md2010covert}
# 	\item \publication{10.1007/978-3-642-13577-4_18}
# 	\item \publication{10.1007/978-3-642-10619-4_22}
# 	\item \publication{amiruzzaman2008embeddedsejong}
# 	\item \publication{wadud2008bottom}
# 	\item \publication{kim2008improved}
# 	\item \publication{4721339}
# 	\item \publication{4743406}
# 	\item \publication{4743420}
# 	\item \publication{md2008embedded}
# 	\item \publication{zhang2008new}
# 	\item \publication{amiruzzaman2008embedded}
# 	\item \publication{md2008study}
# 	\item \publication{md2007embedded}
# 	\item \publication{son2007network}
# 	\item \publication{1307869}
# 	\item \publication{sohel2003fingerprint}
# \end{enumerate}

# %%
# !pip install pybtex
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      -------------------------------------- 561.4/561.4 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.01 in c:\users\mamiruzz\appdata\local\programs\python\python38-32\lib\site-packages (from pybtex) (6.0)
# Requirement already satisfied: six in c:\users\mamiruzz\appdata\local\programs\python\python38-32\lib\site-packages (from pybtex) (1.14.0)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: latexcodec, pybtex
# Successfully installed latexcodec-3.0.0 pybtex-0.24.0
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\users\mamiruzz\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
bibtex = """@ARTICLE{Cesar2013,
  author = {Jean César},
  title = {An amazing title},
  year = {2013},
  month = jan,
  volume = {12},
  pages = {12--23},
  journal = {Nice Journal},
  abstract = {This is an abstract. This line should be long enough to test
     multilines...},
  comments = {A comment},
  keywords = {keyword1, keyword2}
}
"""

with open('bibtex.bib', 'w') as bibfile:
    bibfile.write(bibtex)

# %%
import bibtexparser

with open('bibtex.bib') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

print(bib_database.entries)
# Out:
# [{'keywords': 'keyword1, keyword2', 'comments': 'A comment', 'abstract': 'This is an abstract. This line should be long enough to test\nmultilines...', 'journal': 'Nice Journal', 'pages': '12--23', 'volume': '12', 'month': 'January', 'year': '2013', 'title': 'An amazing title', 'author': 'Jean César', 'ENTRYTYPE': 'article', 'ID': 'Cesar2013'}]
