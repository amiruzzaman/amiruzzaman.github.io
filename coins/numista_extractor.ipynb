# %%
import requests
from bs4 import BeautifulSoup
import json

def extract_numista_features(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        features = {}
        
        # Numista organizes features in a table with id 'coin_features'
        features_table = soup.find('table', {'id': 'coin_features'})
        
        if features_table:
            rows = features_table.find_all('tr')
            for row in rows:
                header = row.find('th')
                data = row.find('td')
                
                if header and data:
                    key = header.get_text(strip=True)
                    # Clean up the value (remove extra whitespace/newlines)
                    value = " ".join(data.get_text().split())
                    features[key] = value
        
        return features

    except Exception as e:
        return {"error": str(e)}

# URL for the 50 Yen - Shōwa (1967-1988 version)
url = "https://en.numista.com/catalogue/pieces1026.html"
coin_data = extract_numista_features(url)

# Output as JSON
print(json.dumps(coin_data, indent=4, ensure_ascii=False))
# Out:
# {}

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_numista(url):
    print(f"Connecting to: {url}...")
    
    # Headers are crucial to avoid being blocked
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
    }
    
    try:
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        
        # Check if the request was successful
        if response.status_code != 200:
            return {"error": f"Failed to load page. Status code: {response.status_code}"}

        soup = BeautifulSoup(response.text, 'html.parser')
        features = {}

        # Look for the specific table by ID
        features_table = soup.find('table', {'id': 'coin_features'})
        
        if not features_table:
            # Fallback: Look for any table that contains the word "Issuer" 
            # (Common in the features section)
            features_table = soup.find('th', string='Issuer').find_parent('table') if soup.find('th', string='Issuer') else None

        if features_table:
            for row in features_table.find_all('tr'):
                th = row.find('th')
                td = row.find('td')
                if th and td:
                    key = th.get_text(strip=True)
                    value = td.get_text(strip=True).replace('\xa0', ' ')
                    features[key] = value
            return features
        else:
            return {"error": "Could not find the Features section on this page."}

    except Exception as e:
        return {"error": f"An error occurred: {str(e)}"}

# Target URL (The specific 1967-1988 Shōwa 50 Yen)
coin_url = "https://en.numista.com/catalogue/pieces1026.html"

data = scrape_numista(coin_url)

# Print the result
if "error" in data:
    print(f"❌ {data['error']}")
else:
    print("✅ Success! Data extracted:")
    print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# Connecting to: https://en.numista.com/catalogue/pieces1026.html...
# ✅ Success! Data extracted:
# {
#     "Issuer": "Japan",
#     "Emperor": "Shōwa(1926-1989)",
#     "Type": "Standard circulation coins",
#     "Years": "42-63                (1967-1988)",
#     "Calendar": "Japanese - Shōwa era",
#     "Value": "50 Yen50 JPY = USD 0.31",
#     "Currency": "Yen (1871-date)",
#     "Composition": "Copper-nickel(75% Copper, 25% Nickel)",
#     "Weight": "4 g",
#     "Diameter": "21 mm",
#     "Thickness": "1.7 mm",
#     "Shape": "Round with a round hole",
#     "Technique": "Milled",
#     "Orientation": "Medal alignment ↑↑",
#     "Number": "N#1026",
#     "References": "Y# 81R. S. Yeoman's Modern & Current World Coins(6 volumes).,JNDA# 02-7Japan Numismatic Dealers Association (publisher).日本貨幣カタログ. Japan Numismatic Dealers Association, Tokyo, Japan (37 volumes).,Schön# 58Battenberg Gietl Verlag (publisher).Weltmünzkatalog. Battenberg Gietl Verlag, Regenstauf, Bavaria, Germany (4 volumes)."
# }

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_numista(url):
    print(f"Connecting to: {url}...")
    
    # Headers are crucial to avoid being blocked
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
    }
    
    try:
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        
        # Check if the request was successful
        if response.status_code != 200:
            return {"error": f"Failed to load page. Status code: {response.status_code}"}

        soup = BeautifulSoup(response.text, 'html.parser')
        features = {}

        # Look for the specific table by ID
        features_table = soup.find('table', {'id': 'coin_features'})
        
        if not features_table:
            # Fallback: Look for any table that contains the word "Issuer" 
            # (Common in the features section)
            features_table = soup.find('th', string='Issuer').find_parent('table') if soup.find('th', string='Issuer') else None

        if features_table:
            for row in features_table.find_all('tr'):
                th = row.find('th')
                td = row.find('td')
                if th and td:
                    key = th.get_text(strip=True)
                    value = td.get_text(strip=True).replace('\xa0', ' ')
                    features[key] = value
            return features
        else:
            return {"error": "Could not find the Features section on this page."}

    except Exception as e:
        return {"error": f"An error occurred: {str(e)}"}

# Target URL (The specific 1967-1988 Shōwa 50 Yen)
coin_url = "https://en.numista.com/210867"

data = scrape_numista(coin_url)

# Print the result
if "error" in data:
    print(f"❌ {data['error']}")
else:
    print("✅ Success! Data extracted:")
    print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# Connecting to: https://en.numista.com/210867...
# ✅ Success! Data extracted:
# {
#     "Issuer": "Pakistan",
#     "Issuing bank": "State Bank of Pakistan(بینک دَولتِ پاکِستان‎)",
#     "Period": "Islamic Republic(1956-date)",
#     "Type": "Standard circulation banknotes",
#     "Years": "2006-2025",
#     "Value": "1000 Rupees1000 PKR = USD 3.58",
#     "Currency": "Rupee (decimalized, 1961-date)",
#     "Composition": "Paper",
#     "Size": "155 × 65 mm",
#     "Shape": "Rectangular",
#     "Issued": "26 February 2007",
#     "Number": "N#210867",
#     "References": "P# 50Standard Catalog of World Paper Money(10 volumes).,TBB# 238Owen W. Linzmayer.The Banknote Book(4 volumes)."
# }

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_numista(url):
    print(f"Connecting to: {url}...")
    
    # Headers are crucial to avoid being blocked
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
    }
    
    try:
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        
        # Check if the request was successful
        if response.status_code != 200:
            return {"error": f"Failed to load page. Status code: {response.status_code}"}

        soup = BeautifulSoup(response.text, 'html.parser')
        features = {}

        # Look for the specific table by ID
        features_table = soup.find('table', {'id': 'coin_features'})
        
        if not features_table:
            # Fallback: Look for any table that contains the word "Issuer" 
            # (Common in the features section)
            features_table = soup.find('th', string='Issuer').find_parent('table') if soup.find('th', string='Issuer') else None

        if features_table:
            for row in features_table.find_all('tr'):
                th = row.find('th')
                td = row.find('td')
                if th and td:
                    key = th.get_text(strip=True)
                    value = td.get_text(strip=True).replace('\xa0', ' ')
                    features[key] = value
            return features
        else:
            return {"error": "Could not find the Features section on this page."}

    except Exception as e:
        return {"error": f"An error occurred: {str(e)}"}

# Target URL (The specific 1967-1988 Shōwa 50 Yen)
coin_url = "https://en.numista.com/763"

data = scrape_numista(coin_url)

# Print the result
if "error" in data:
    print(f"❌ {data['error']}")
else:
    print("✅ Success! Data extracted:")
    print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# Connecting to: https://en.numista.com/763...
# ✅ Success! Data extracted:
# {
#     "Issuer": "Soviet Union(Russia)",
#     "Period": "Soviet Union(1922-1991)",
#     "Type": "Standard circulation coins",
#     "Years": "1961-1991",
#     "Value": "20 Kopecks\n                (0.20&nbspSUR)",
#     "Currency": "Sixth Rouble (1961-1991)",
#     "Composition": "Nickel brass",
#     "Weight": "3.4 g",
#     "Diameter": "21.8 mm",
#     "Thickness": "1.4 mm",
#     "Shape": "Round",
#     "Technique": "Milled",
#     "Orientation": "Medal alignment ↑↑",
#     "Demonetized": "1991",
#     "Number": "N#763",
#     "References": "Y# 132Richard Sperry Yeoman.R. S. Yeoman's Modern & Current World Coins(15 volumes).,Schön# 81Battenberg Gietl Verlag (publisher).Weltmünzkatalog. Battenberg Gietl Verlag, Regenstauf, Bavaria, Germany (4 volumes)."
# }

# %%
json.dumps(data["Value"])
# Out:
# '"20 Kopecks\\n                (0.20&nbspSUR)"'

# %%
text = json.dumps(data["Value"])
# 1. Strip the outer quotes
text = text.strip('"\'')

# 2. Explicitly replace the literal string "\n" with a space
text = text.replace("\\n", " ")

# 2. Replace the HTML entity with a space
text = text.replace("&nbsp", " ")

# 3. Smash the extra spaces and newlines together
cleaned = " ".join(text.split())

cleaned
# Out:
# '20 Kopecks (0.20 SUR)'

# %%
# 1. Extract the raw string directly (avoids adding extra json.dumps quotes)
raw_value = data["Value"]

# 2. Fix the line breaks, remove the HTML entity, and collapse the massive spacing
cleaned = " ".join(raw_value.replace("\n", " ").replace("&nbsp", " ").split())

print(cleaned)
# Output: 20 Kopecks (0.20 SUR)
# Out:
# 20 Kopecks (0.20 SUR)

# %%
json.dumps(data["Composition"])
# Out:
# '"Nickel brass"'

# %%
# 1. Grab the raw value and convert the whole thing to lowercase
raw_composition = data["Composition"].lower()

# 2. Add "Composition " to the front
modified_composition = f"Composition {raw_composition}"

# 3. If you need it JSON-encoded (with the outer quotes)
final_json_string = json.dumps(modified_composition)

print(final_json_string)
# Output: "Composition aluminium-nickel bronze (92% copper, 6% aluminium, 2% nickel)"
# Out:
# "Composition nickel brass"

# %%
# 1. Clean the Value field (removes newlines, &nbsp, and collapses extra spaces)
cleaned_value = " ".join(data["Value"].replace("\n", " ").replace("&nbsp", " ").split())

# 2. Format the Composition field (lowercases it and adds the prefix)
cleaned_composition = f"Composition {data['Composition'].lower()}"

# 3. Combine them separated by a period
combined_result = f"{cleaned_value}. {cleaned_composition}"

# 4. (Optional) Only use json.dumps if you absolutely need the final output wrapped in JSON quotes
final_output = json.dumps(combined_result)

print(final_output)
# Output: "20 Kopecks (0.20 SUR). Composition aluminium-nickel bronze (92% copper, 6% aluminium, 2% nickel)"
# Out:
# "20 Kopecks (0.20 SUR). Composition nickel brass"

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_numista(url):
    print(f"Connecting to: {url}...")
    
    # Headers are crucial to avoid being blocked
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
    }
    
    try:
        session = requests.Session()
        response = session.get(url, headers=headers, timeout=10)
        
        # Check if the request was successful
        if response.status_code != 200:
            return {"error": f"Failed to load page. Status code: {response.status_code}"}

        soup = BeautifulSoup(response.text, 'html.parser')
        features = {}

        # Look for the specific table by ID
        features_table = soup.find('table', {'id': 'coin_features'})
        
        if not features_table:
            # Fallback: Look for any table that contains the word "Issuer" 
            # (Common in the features section)
            features_table = soup.find('th', string='Issuer').find_parent('table') if soup.find('th', string='Issuer') else None

        if features_table:
            for row in features_table.find_all('tr'):
                th = row.find('th')
                td = row.find('td')
                if th and td:
                    key = th.get_text(strip=True)
                    value = td.get_text(strip=True).replace('\xa0', ' ')
                    features[key] = value
            return features
        else:
            return {"error": "Could not find the Features section on this page."}

    except Exception as e:
        return {"error": f"An error occurred: {str(e)}"}

# Target URL (The specific 1967-1988 Shōwa 50 Yen)
coin_url = "https://en.numista.com/208928"

data = scrape_numista(coin_url)

# Print the result
if "error" in data:
    print(f"❌ {data['error']}")
else:
    print("✅ Success! Data extracted:")
    print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# Connecting to: https://en.numista.com/208928...
# ✅ Success! Data extracted:
# {
#     "Issuer": "Morocco",
#     "Issuing bank": "Bank Al-Maghrib(بنك المغرب)",
#     "King": "Hassan II                    (الحسن الثاني)(1961-1999)",
#     "Type": "Standard circulation banknotes",
#     "Year": "1416                (1996)",
#     "Calendar": "Islamic (Hijri)",
#     "Value": "20 Dirhams\n                (20&nbspMAD)",
#     "Currency": "Dirham (1960-date)",
#     "Composition": "Paper",
#     "Size": "130 × 68 mm",
#     "Shape": "Rectangular",
#     "Demonetized": "1 January 2026",
#     "Number": "N#208928",
#     "References": "P# 67Standard Catalog of World Paper Money(10 volumes).,TBB# 508Owen W. Linzmayer.The Banknote Book(4 volumes)."
# }
